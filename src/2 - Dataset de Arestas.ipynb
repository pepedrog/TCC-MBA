# %%
import aux.sao_paulo_shapefile as sp_shp
import aux.sao_paulo_graph as sp_graph
import aux.preprocess_congestion as cong
import aux.preprocess_accidents as acc
import folium
from scipy.spatial import KDTree

# se nenessário recarregar os arquivos auxiliares
from importlib import reload
reload(sp_shp)
reload(sp_graph)
reload(cong)
reload(acc)
import numpy as np
import pandas as pd
from datetime import datetime

# %% [markdown]
# #### Criação do Grafo (5 min)

# %%
print('{}\t Fazendo leitura do arquivo (1 min)'.format(datetime.now().strftime('%H:%M:%S')))
gdf = sp_shp.read_and_process_file('data/logradouros/SIRGAS_SHP_logradouronbl_line.shp')

print('{}\t Iniciando criação do grafo (1 min)'.format(datetime.now().strftime('%H:%M:%S')))
G = sp_graph.create_and_process_graph (gdf)

print('{}\t Fim da criação do grafo'.format(datetime.now().strftime('%H:%M:%S')))
# Out:
# 22:03:00	 Fazendo leitura do arquivo (1 min)
# 22:03:21	 Iniciando criação do grafo (1 min)
# 22:04:22	 Fim da criação do grafo

# %% [markdown]
# #### Inserção dos dados de Acidentes

# %%
print('{}\tIniciando atribuição do acidentes nas arestas (1 min)'.format(datetime.now().strftime('%H:%M:%S')))

df_acidentes = pd.read_csv('data/acidentes/df_acidentes.csv')
df_acidentes = df_acidentes[['chave', 'data', 'hora', 'dia_semana',
                'latitude', 'longitude', 'tipo_acidente', 'qtde_vitimas']]
df_acidentes['index'] = range(len(df_acidentes))
print('{}\tBase de acidentes: {} registros'.format(datetime.now().strftime('%H:%M:%S'), (len(df_acidentes)))) # 216010 
      
acc.put_accidents_on_edges(G, df_acidentes)
print('{}\tFinalizando atribuição do acidentes nas arestas'.format(datetime.now().strftime('%H:%M:%S')))
# Out:
# 22:04:22	Iniciando atribuição do acidentes nas arestas (1 min)
# 22:04:24	Base de acidentes: 216010 registros
# 22:05:11	Finalizando atribuição do acidentes nas arestas

# %% [markdown]
# #### Inserção dos dados de Congestionamentos

# %%
df_congestionamentos = pd.read_csv('data/congestionamentos_pre_processado.csv')
df_congestionamentos.fillna('', inplace = True)
df_congestionamentos['index'] = range(len(df_congestionamentos))
print('{}\tBase de acidentes: {} registros'.format(datetime.now().strftime('%H:%M:%S'), (len(df_congestionamentos)))) #832525 

df_pontos = pd.read_csv('data/coordenadas_congestionamentos.csv')
df_pontos = df_pontos.fillna('')
print('{}\tBase de pontos de referencia: {} registros'.format(datetime.now().strftime('%H:%M:%S'), (len(df_pontos)))) #3447
# Out:
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\569977181.py:1: DtypeWarning: Columns (5,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_congestionamentos = pd.read_csv('data/congestionamentos_pre_processado.csv')
# 22:05:18	Base de acidentes: 832525 registros
# 22:05:18	Base de pontos de referencia: 3447 registros

# %%
print('{}\t Identificando as arestas de cada corredor (5 min) '.format(datetime.now().strftime('%H:%M:%S')))
arestas_por_corredor = cong.get_dict_edges_corridors (G, df_congestionamentos)

def get_subgraphs (G, edges_dict, neighborhood_depth = 6):
    subgraphs = { }
    for corridor, e in edges_dict.items():
        subgraphs[corridor] = sp_graph.generate_subgraph(G, e['arestas'], neighborhood_depth)
    return subgraphs

print('{}\t Particionando subgrafos (1 min)'.format(datetime.now().strftime('%H:%M:%S')))

subgraphs = get_subgraphs(G, arestas_por_corredor)

print('{}\t Fim do processamento dos corredores'.format(datetime.now().strftime('%H:%M:%S')))
# Out:
# 22:05:18	 Identificando as arestas de cada corredor (5 min)
# 22:08:36	 Particionando subgrafos (1 min)
# 22:08:49	 Fim do processamento dos corredores

# %% [markdown]
# ### Geração da base de arestas

# %%
def gera_arestas_acidentes(arestas_do_corredor, acidentes_inseridos):
    edges_data = []
    n = len(arestas_do_corredor) 
    print(f"{datetime.now().strftime('%H:%M:%S')}\tInicio acidentes \t\t{n} arestas")
    
    i = 0
    for e in arestas_do_corredor:
        if 'acidentes' in e[2]:
            for a in e[2]['acidentes']:
                if a[0] not in acidentes_inseridos:
                    i += 1
                    acidentes_inseridos.add(a[0])
                    edges_data.append([e[0], e[1], e[2]['geometry'], *a, None])
                    
    print(f"{datetime.now().strftime('%H:%M:%S')}\tFim acidentes \t\t\t{i} acidentes inseridos")
    return edges_data

# %%
def encontra_no_mais_proximo(ponto, nodes):
    # necessario por conta de erros numericos D:
    tree = KDTree(nodes)
    d, i = tree.query(ponto)
    return nodes[i]

def obtem_ponto(subgraph, df_pontos, corredor, referencia, tipo, distancia):
    ponto = eval(df_pontos.loc[
        df_pontos['corredor']  == corredor].loc[
        df_pontos['ponto']     == referencia].loc[
        df_pontos['tipo']      == tipo].loc[
        df_pontos['distancia'] == distancia].iloc[0]['vertice'])
    
    ponto = (round(ponto[0], 10), round(ponto[1], 10))
    
    if ponto not in subgraph.nodes():
        ponto = encontra_no_mais_proximo(ponto, list(subgraph.nodes()))
    
    return ponto

def gera_arestas_caminho(subgraph, df_pontos, caminho, corredor, erros):
    ponto_inicial = obtem_ponto(subgraph, df_pontos, corredor, caminho[0], caminho[1], caminho[2])
    ponto_final = obtem_ponto(subgraph, df_pontos, corredor, caminho[3], caminho[4], caminho[5])

    try:
        S = cong.encontra_caminho(subgraph, ponto_inicial, ponto_final)
    except Exception as e:
        erros.append([corredor, *caminho, e])
        print('--- erro ---', len(erro))
        return []
    return S.edges(data = True)
    
    
def gera_arestas_congestionamentos(df_pontos, df_congestionamentos, subgraph, corredor, erros):
    edges_data = []
    df_cong = df_congestionamentos.query(f'corredor == "{corredor}"')
    
    df_pontos_aux = df_pontos.loc[df_pontos['corredor'] == corredor]
    
    caminhos = df_cong.groupby(['referencia_a', 'tipo_a', 'distancia_a',
                                'referencia_z', 'tipo_z', 'distancia_z'])
    
    print(f"{datetime.now().strftime('%H:%M:%S')}\tInicio congestionamentos \t{len(caminhos)} caminhos")
    
    arestas_congestionamentos = []

    for caminho, congs in caminhos:
        arestas_caminho = gera_arestas_caminho(subgraph, df_pontos, caminho, corredor, erros)
        arestas_congestionamentos.extend(arestas_caminho)
        for e in arestas_caminho:
            for _, c in congs.iterrows():
                [data, hora] = c['data'].split(' ') if ' ' in c['data'] else [c['data'], None]
                edges_data.append([e[0], e[1], e[2]['geometry'], 'c_' + str(c['index']),
                                   data, hora, None, 
                                   None, None,
                                   c['tamanho']])
                
    subgafo_restrito = sp_graph.generate_subgraph(subgraph, arestas_congestionamentos, 4)

    print(f"{datetime.now().strftime('%H:%M:%S')}\tFim congestionamentos \t\t{len(df_cong)} congestionamentos")
    return edges_data, subgafo_restrito

# %%
# tempo estimado de processamento: 30 minutos

acidentes_inseridos = set()
erros = []
total = len(subgraphs)
i = 0
for S in subgraphs:
    print('*'*100)
    c = S.split('/')[0].strip()
    print(f'{i}/{total}\t{c}')
    i += 1
    
    arestas_congestionamentos, subgrafo_restrito = gera_arestas_congestionamentos(df_pontos, df_congestionamentos, 
                                                               subgraphs[S], S.strip(), erros)

    arestas_acidentes = gera_arestas_acidentes(subgrafo_restrito.edges(data = True), acidentes_inseridos)
    
    arestas = arestas_congestionamentos + arestas_acidentes
    
    df_arestas = pd.DataFrame(data = arestas, 
                              columns = ['vertice_a', 'vertice_b', 'geometry', 'index', 
                                         'data', 'hora', 'dia_semana', 
                                         'tipo_acidente', 'qtde_vitimas',
                                         'tamanho_congestionamento'])
    
    df_arestas.to_csv('data/arestas/arestas_' + c + '.csv')
    print(f"{datetime.now().strftime('%H:%M:%S')}\tFim do processamento do corredor")
# Out:
# ****************************************************************************************************
# 0/167	AL STO AMARO
# 22:11:49	Inicio congestionamentos 	1 caminhos
# 22:11:49	Fim congestionamentos 		9 congestionamentos
# 22:11:49	Inicio acidentes 		172 arestas
# 22:11:49	Fim acidentes 			764 acidentes inseridos
# 22:11:50	Fim do processamento do corredor
# ****************************************************************************************************
# 1/167	AV  I INTERLAGOS
# 22:11:50	Inicio congestionamentos 	164 caminhos
# 22:12:00	Fim congestionamentos 		5591 congestionamentos
# 22:12:00	Inicio acidentes 		1367 arestas
# 22:12:00	Fim acidentes 			3717 acidentes inseridos
# 22:12:08	Fim do processamento do corredor
# ****************************************************************************************************
# 2/167	AV ADOLFO PINHEIRO
# 22:12:08	Inicio congestionamentos 	4 caminhos
# 22:12:08	Fim congestionamentos 		24 congestionamentos
# 22:12:08	Inicio acidentes 		202 arestas
# 22:12:08	Fim acidentes 			312 acidentes inseridos
# 22:12:09	Fim do processamento do corredor
# ****************************************************************************************************
# 3/167	AV ANGELICA
# 22:12:09	Inicio congestionamentos 	2 caminhos
# 22:12:09	Fim congestionamentos 		4 congestionamentos
# 22:12:09	Inicio acidentes 		282 arestas
# 22:12:09	Fim acidentes 			707 acidentes inseridos
# 22:12:09	Fim do processamento do corredor
# ****************************************************************************************************
# 4/167	AV ANTONIO JOAQUIM DE MOURA ANDRADE
# 22:12:09	Inicio congestionamentos 	44 caminhos
# 22:12:16	Fim congestionamentos 		16405 congestionamentos
# 22:12:16	Inicio acidentes 		267 arestas
# 22:12:16	Fim acidentes 			461 acidentes inseridos
# 22:12:20	Fim do processamento do corredor
# ****************************************************************************************************
# 5/167	AV ARICANDUVA
# 22:12:20	Inicio congestionamentos 	386 caminhos
# 22:12:54	Fim congestionamentos 		19406 congestionamentos
# 22:12:54	Inicio acidentes 		2099 arestas
# 22:12:54	Fim acidentes 			4467 acidentes inseridos
# 22:13:07	Fim do processamento do corredor
# ****************************************************************************************************
# 6/167	AV ATLANTICA
# 22:13:08	Inicio congestionamentos 	63 caminhos
# 22:13:13	Fim congestionamentos 		3503 congestionamentos
# 22:13:13	Inicio acidentes 		863 arestas
# 22:13:13	Fim acidentes 			1447 acidentes inseridos
# 22:13:16	Fim do processamento do corredor
# ****************************************************************************************************
# 7/167	AV BERNARDINO DE CAMPOS
# 22:13:16	Inicio congestionamentos 	103 caminhos
# 22:13:21	Fim congestionamentos 		1814 congestionamentos
# 22:13:21	Inicio acidentes 		1626 arestas
# 22:13:21	Fim acidentes 			2683 acidentes inseridos
# 22:13:23	Fim do processamento do corredor
# ****************************************************************************************************
# 8/167	AV BRASIL
# 22:13:23	Inicio congestionamentos 	35 caminhos
# 22:13:24	Fim congestionamentos 		282 congestionamentos
# 22:13:24	Inicio acidentes 		593 arestas
# 22:13:24	Fim acidentes 			1069 acidentes inseridos
# 22:13:24	Fim do processamento do corredor
# ****************************************************************************************************
# 9/167	AV BRAZ LEME
# 22:13:24	Inicio congestionamentos 	53 caminhos
# 22:13:26	Fim congestionamentos 		2924 congestionamentos
# 22:13:26	Inicio acidentes 		546 arestas
# 22:13:26	Fim acidentes 			877 acidentes inseridos
# 22:13:27	Fim do processamento do corredor
# ****************************************************************************************************
# 10/167	AV BRIG FARIA LIMA
# 22:13:27	Inicio congestionamentos 	57 caminhos
# 22:13:29	Fim congestionamentos 		643 congestionamentos
# 22:13:29	Inicio acidentes 		1066 arestas
# 22:13:29	Fim acidentes 			2202 acidentes inseridos
# 22:13:30	Fim do processamento do corredor
# ****************************************************************************************************
# 11/167	AV BRIG LUIS ANTONIO
# 22:13:30	Inicio congestionamentos 	74 caminhos
# 22:13:31	Fim congestionamentos 		461 congestionamentos
# 22:13:31	Inicio acidentes 		1071 arestas
# 22:13:32	Fim acidentes 			1669 acidentes inseridos
# 22:13:32	Fim do processamento do corredor
# ****************************************************************************************************
# 12/167	AV CARLOS CALDEIRA FILHO
# 22:13:32	Inicio congestionamentos 	53 caminhos
# 22:13:36	Fim congestionamentos 		2517 congestionamentos
# 22:13:36	Inicio acidentes 		392 arestas
# 22:13:36	Fim acidentes 			1090 acidentes inseridos
# 22:13:39	Fim do processamento do corredor
# ****************************************************************************************************
# 13/167	AV CELSO GARCIA
# 22:13:39	Inicio congestionamentos 	133 caminhos
# 22:13:43	Fim congestionamentos 		2241 congestionamentos
# 22:13:43	Inicio acidentes 		1215 arestas
# 22:13:43	Fim acidentes 			2102 acidentes inseridos
# 22:13:45	Fim do processamento do corredor
# ****************************************************************************************************
# 14/167	AV CIDADE JARDIM
# 22:13:45	Inicio congestionamentos 	55 caminhos
# 22:13:50	Fim congestionamentos 		12528 congestionamentos
# 22:13:50	Inicio acidentes 		584 arestas
# 22:13:50	Fim acidentes 			204 acidentes inseridos
# 22:13:53	Fim do processamento do corredor
# ****************************************************************************************************
# 15/167	AV CONS CARRAO
# 22:13:53	Inicio congestionamentos 	42 caminhos
# 22:13:54	Fim congestionamentos 		358 congestionamentos
# 22:13:54	Inicio acidentes 		818 arestas
# 22:13:54	Fim acidentes 			908 acidentes inseridos
# 22:13:54	Fim do processamento do corredor
# ****************************************************************************************************
# 16/167	AV CORIFEU DE A MARQUES
# 22:13:54	Inicio congestionamentos 	27 caminhos
# 22:13:55	Fim congestionamentos 		273 congestionamentos
# 22:13:55	Inicio acidentes 		850 arestas
# 22:13:55	Fim acidentes 			1162 acidentes inseridos
# 22:13:55	Fim do processamento do corredor
# ****************************************************************************************************
# 17/167	AV DO ESTADO
# 22:13:55	Inicio congestionamentos 	246 caminhos
# 22:14:26	Fim congestionamentos 		27622 congestionamentos
# 22:14:26	Inicio acidentes 		1646 arestas
# 22:14:26	Fim acidentes 			4926 acidentes inseridos
# 22:14:39	Fim do processamento do corredor
# ****************************************************************************************************
# 18/167	AV DOS BANDEIRANTES
# 22:14:39	Inicio congestionamentos 	574 caminhos
# 22:15:42	Fim congestionamentos 		31660 congestionamentos
# 22:15:42	Inicio acidentes 		1497 arestas
# 22:15:42	Fim acidentes 			2501 acidentes inseridos
# 22:16:05	Fim do processamento do corredor
# ****************************************************************************************************
# 19/167	AV DOS TAJURAS
# 22:16:05	Inicio congestionamentos 	7 caminhos
# 22:16:06	Fim congestionamentos 		806 congestionamentos
# 22:16:06	Inicio acidentes 		214 arestas
# 22:16:06	Fim acidentes 			251 acidentes inseridos
# 22:16:06	Fim do processamento do corredor
# ****************************************************************************************************
# 20/167	AV DR ARNALDO
# 22:16:06	Inicio congestionamentos 	34 caminhos
# 22:16:08	Fim congestionamentos 		2377 congestionamentos
# 22:16:08	Inicio acidentes 		396 arestas
# 22:16:08	Fim acidentes 			775 acidentes inseridos
# 22:16:08	Fim do processamento do corredor
# ****************************************************************************************************
# 21/167	AV DR CHUCRI ZAIDAN
# 22:16:09	Inicio congestionamentos 	9 caminhos
# 22:16:09	Fim congestionamentos 		610 congestionamentos
# 22:16:09	Inicio acidentes 		307 arestas
# 22:16:09	Fim acidentes 			716 acidentes inseridos
# 22:16:10	Fim do processamento do corredor
# ****************************************************************************************************
# 22/167	AV DR FRANCISCO MESQUITA
# 22:16:10	Inicio congestionamentos 	7 caminhos
# 22:16:10	Fim congestionamentos 		424 congestionamentos
# 22:16:10	Inicio acidentes 		278 arestas
# 22:16:10	Fim acidentes 			299 acidentes inseridos
# 22:16:10	Fim do processamento do corredor
# ****************************************************************************************************
# 23/167	AV DR GASTAO VIDIGAL
# 22:16:10	Inicio congestionamentos 	75 caminhos
# 22:16:13	Fim congestionamentos 		1064 congestionamentos
# 22:16:13	Inicio acidentes 		448 arestas
# 22:16:13	Fim acidentes 			1024 acidentes inseridos
# 22:16:13	Fim do processamento do corredor
# ****************************************************************************************************
# 24/167	AV DR GUILHERME DUMONT VILARES
# 22:16:13	Inicio congestionamentos 	2 caminhos
# 22:16:13	Fim congestionamentos 		100 congestionamentos
# 22:16:13	Inicio acidentes 		148 arestas
# 22:16:13	Fim acidentes 			299 acidentes inseridos
# 22:16:13	Fim do processamento do corredor
# ****************************************************************************************************
# 25/167	AV ELISEU DE ALMEIDA
# 22:16:14	Inicio congestionamentos 	2 caminhos
# 22:16:14	Fim congestionamentos 		88 congestionamentos
# 22:16:14	Inicio acidentes 		130 arestas
# 22:16:14	Fim acidentes 			290 acidentes inseridos
# 22:16:14	Fim do processamento do corredor
# ****************************************************************************************************
# 26/167	AV ENG LUIS CARLOS BERRINI
# 22:16:14	Inicio congestionamentos 	19 caminhos
# 22:16:14	Fim congestionamentos 		784 congestionamentos
# 22:16:14	Inicio acidentes 		465 arestas
# 22:16:14	Fim acidentes 			533 acidentes inseridos
# 22:16:15	Fim do processamento do corredor
# ****************************************************************************************************
# 27/167	AV ERMANO MARCHETTI
# 22:16:15	Inicio congestionamentos 	47 caminhos
# 22:16:17	Fim congestionamentos 		2004 congestionamentos
# 22:16:17	Inicio acidentes 		332 arestas
# 22:16:17	Fim acidentes 			625 acidentes inseridos
# 22:16:19	Fim do processamento do corredor
# ****************************************************************************************************
# 28/167	AV ESCOLA POLITECNICA
# 22:16:19	Inicio congestionamentos 	7 caminhos
# 22:16:19	Fim congestionamentos 		210 congestionamentos
# 22:16:19	Inicio acidentes 		139 arestas
# 22:16:19	Fim acidentes 			143 acidentes inseridos
# 22:16:19	Fim do processamento do corredor
# ****************************************************************************************************
# 29/167	AV EUSEBIO MATOSO
# 22:16:19	Inicio congestionamentos 	76 caminhos
# 22:16:24	Fim congestionamentos 		4484 congestionamentos
# 22:16:24	Inicio acidentes 		815 arestas
# 22:16:24	Fim acidentes 			1816 acidentes inseridos
# 22:16:26	Fim do processamento do corredor
# ****************************************************************************************************
# 30/167	AV F1 - JANGADEIRO
# 22:16:26	Inicio congestionamentos 	1 caminhos
# 22:16:26	Fim congestionamentos 		5 congestionamentos
# 22:16:26	Inicio acidentes 		127 arestas
# 22:16:26	Fim acidentes 			27 acidentes inseridos
# 22:16:27	Fim do processamento do corredor
# ****************************************************************************************************
# 31/167	AV FRANCISCO MATARAZZO
# 22:16:27	Inicio congestionamentos 	110 caminhos
# 22:16:36	Fim congestionamentos 		7680 congestionamentos
# 22:16:36	Inicio acidentes 		527 arestas
# 22:16:36	Fim acidentes 			785 acidentes inseridos
# 22:16:40	Fim do processamento do corredor
# ****************************************************************************************************
# 32/167	AV GUARAPIRANGA
# 22:16:40	Inicio congestionamentos 	67 caminhos
# 22:16:44	Fim congestionamentos 		4083 congestionamentos
# 22:16:44	Inicio acidentes 		348 arestas
# 22:16:44	Fim acidentes 			985 acidentes inseridos
# 22:16:46	Fim do processamento do corredor
# ****************************************************************************************************
# 33/167	AV GUIDO CALOI
# 22:16:46	Inicio congestionamentos 	15 caminhos
# 22:16:49	Fim congestionamentos 		2826 congestionamentos
# 22:16:49	Inicio acidentes 		239 arestas
# 22:16:49	Fim acidentes 			713 acidentes inseridos
# 22:16:50	Fim do processamento do corredor
# ****************************************************************************************************
# 34/167	AV I INTERLAGOS
# 22:16:50	Inicio congestionamentos 	212 caminhos
# 22:17:03	Fim congestionamentos 		6197 congestionamentos
# 22:17:03	Inicio acidentes 		1424 arestas
# 22:17:03	Fim acidentes 			57 acidentes inseridos
# 22:17:07	Fim do processamento do corredor
# ****************************************************************************************************
# 35/167	AV IBIRAPUERA
# 22:17:07	Inicio congestionamentos 	86 caminhos
# 22:17:10	Fim congestionamentos 		772 congestionamentos
# 22:17:10	Inicio acidentes 		917 arestas
# 22:17:10	Fim acidentes 			1134 acidentes inseridos
# 22:17:11	Fim do processamento do corredor
# ****************************************************************************************************
# 36/167	AV INAJAR DE SOUZA
# 22:17:11	Inicio congestionamentos 	19 caminhos
# 22:17:12	Fim congestionamentos 		1729 congestionamentos
# 22:17:12	Inicio acidentes 		559 arestas
# 22:17:12	Fim acidentes 			799 acidentes inseridos
# 22:17:13	Fim do processamento do corredor
# ****************************************************************************************************
# 37/167	AV IPIRANGA
# 22:17:13	Inicio congestionamentos 	14 caminhos
# 22:17:13	Fim congestionamentos 		193 congestionamentos
# 22:17:13	Inicio acidentes 		423 arestas
# 22:17:13	Fim acidentes 			932 acidentes inseridos
# 22:17:14	Fim do processamento do corredor
# ****************************************************************************************************
# 38/167	AV JAGUARE
# 22:17:14	Inicio congestionamentos 	13 caminhos
# 22:17:14	Fim congestionamentos 		715 congestionamentos
# 22:17:14	Inicio acidentes 		222 arestas
# 22:17:14	Fim acidentes 			165 acidentes inseridos
# 22:17:15	Fim do processamento do corredor
# ****************************************************************************************************
# 39/167	AV JOAO DIAS
# 22:17:15	Inicio congestionamentos 	179 caminhos
# 22:17:27	Fim congestionamentos 		9732 congestionamentos
# 22:17:27	Inicio acidentes 		803 arestas
# 22:17:27	Fim acidentes 			1569 acidentes inseridos
# 22:17:32	Fim do processamento do corredor
# ****************************************************************************************************
# 40/167	AV LIBERDADE
# 22:17:32	Inicio congestionamentos 	13 caminhos
# 22:17:33	Fim congestionamentos 		113 congestionamentos
# 22:17:33	Inicio acidentes 		631 arestas
# 22:17:33	Fim acidentes 			653 acidentes inseridos
# 22:17:33	Fim do processamento do corredor
# ****************************************************************************************************
# 41/167	AV LINEU DE PAULA MACHADO
# 22:17:33	Inicio congestionamentos 	2 caminhos
# 22:17:33	Fim congestionamentos 		402 congestionamentos
# 22:17:33	Inicio acidentes 		130 arestas
# 22:17:33	Fim acidentes 			43 acidentes inseridos
# 22:17:33	Fim do processamento do corredor
# ****************************************************************************************************
# 42/167	AV MARIA COELHO AGUIAR
# 22:17:33	Inicio congestionamentos 	10 caminhos
# 22:17:34	Fim congestionamentos 		800 congestionamentos
# 22:17:34	Inicio acidentes 		195 arestas
# 22:17:34	Fim acidentes 			223 acidentes inseridos
# 22:17:35	Fim do processamento do corredor
# ****************************************************************************************************
# 43/167	AV MARQ DE SAO VICENTE
# 22:17:35	Inicio congestionamentos 	43 caminhos
# 22:17:36	Fim congestionamentos 		1068 congestionamentos
# 22:17:36	Inicio acidentes 		544 arestas
# 22:17:36	Fim acidentes 			659 acidentes inseridos
# 22:17:37	Fim do processamento do corredor
# ****************************************************************************************************
# 44/167	AV MERCURIO
# 22:17:37	Inicio congestionamentos 	15 caminhos
# 22:17:38	Fim congestionamentos 		2079 congestionamentos
# 22:17:38	Inicio acidentes 		229 arestas
# 22:17:38	Fim acidentes 			94 acidentes inseridos
# 22:17:38	Fim do processamento do corredor
# ****************************************************************************************************
# 45/167	AV MORUMBI
# 22:17:38	Inicio congestionamentos 	75 caminhos
# 22:17:44	Fim congestionamentos 		7213 congestionamentos
# 22:17:44	Inicio acidentes 		763 arestas
# 22:17:44	Fim acidentes 			880 acidentes inseridos
# 22:17:47	Fim do processamento do corredor
# ****************************************************************************************************
# 46/167	AV NICOLAS BOER
# 22:17:47	Inicio congestionamentos 	3 caminhos
# 22:17:48	Fim congestionamentos 		1494 congestionamentos
# 22:17:48	Inicio acidentes 		243 arestas
# 22:17:48	Fim acidentes 			381 acidentes inseridos
# 22:17:49	Fim do processamento do corredor
# ****************************************************************************************************
# 47/167	AV NOVE DE JULHO
# 22:17:49	Inicio congestionamentos 	224 caminhos
# 22:17:57	Fim congestionamentos 		6504 congestionamentos
# 22:17:57	Inicio acidentes 		1348 arestas
# 22:17:57	Fim acidentes 			1631 acidentes inseridos
# 22:17:59	Fim do processamento do corredor
# ****************************************************************************************************
# 48/167	AV PACAEMBU
# 22:17:59	Inicio congestionamentos 	58 caminhos
# 22:18:04	Fim congestionamentos 		3999 congestionamentos
# 22:18:04	Inicio acidentes 		758 arestas
# 22:18:04	Fim acidentes 			384 acidentes inseridos
# 22:18:06	Fim do processamento do corredor
# ****************************************************************************************************
# 49/167	AV PAULISTA
# 22:18:06	Inicio congestionamentos 	232 caminhos
# 22:18:16	Fim congestionamentos 		12128 congestionamentos
# 22:18:16	Inicio acidentes 		669 arestas
# 22:18:16	Fim acidentes 			276 acidentes inseridos
# 22:18:19	Fim do processamento do corredor
# ****************************************************************************************************
# 50/167	AV PAULO VI
# 22:18:19	Inicio congestionamentos 	6 caminhos
# 22:18:20	Fim congestionamentos 		85 congestionamentos
# 22:18:20	Inicio acidentes 		368 arestas
# 22:18:20	Fim acidentes 			288 acidentes inseridos
# 22:18:20	Fim do processamento do corredor
# ****************************************************************************************************
# 51/167	AV PE JOSE MARIA
# 22:18:20	Inicio congestionamentos 	4 caminhos
# 22:18:20	Fim congestionamentos 		17 congestionamentos
# 22:18:20	Inicio acidentes 		202 arestas
# 22:18:20	Fim acidentes 			139 acidentes inseridos
# 22:18:20	Fim do processamento do corredor
# ****************************************************************************************************
# 52/167	AV PEDRO ALVARES CABRAL
# 22:18:20	Inicio congestionamentos 	53 caminhos
# 22:18:24	Fim congestionamentos 		3895 congestionamentos
# 22:18:24	Inicio acidentes 		491 arestas
# 22:18:25	Fim acidentes 			52 acidentes inseridos
# 22:18:27	Fim do processamento do corredor
# ****************************************************************************************************
# 53/167	AV PRES JUSCELINO KUBITSCHEK
# 22:18:27	Inicio congestionamentos 	78 caminhos
# 22:18:36	Fim congestionamentos 		10320 congestionamentos
# 22:18:36	Inicio acidentes 		657 arestas
# 22:18:36	Fim acidentes 			185 acidentes inseridos
# 22:18:41	Fim do processamento do corredor
# ****************************************************************************************************
# 54/167	AV PRES TANCREDO NEVES
# 22:18:41	Inicio congestionamentos 	24 caminhos
# 22:18:42	Fim congestionamentos 		319 congestionamentos
# 22:18:42	Inicio acidentes 		421 arestas
# 22:18:42	Fim acidentes 			509 acidentes inseridos
# 22:18:42	Fim do processamento do corredor
# ****************************************************************************************************
# 55/167	AV PROF ABRAAO DE MORAIS
# 22:18:42	Inicio congestionamentos 	58 caminhos
# 22:18:44	Fim congestionamentos 		809 congestionamentos
# 22:18:44	Inicio acidentes 		833 arestas
# 22:18:44	Fim acidentes 			1052 acidentes inseridos
# 22:18:45	Fim do processamento do corredor
# ****************************************************************************************************
# 56/167	AV PROF FRANCISCO MORATO
# 22:18:45	Inicio congestionamentos 	142 caminhos
# 22:18:53	Fim congestionamentos 		10076 congestionamentos
# 22:18:53	Inicio acidentes 		808 arestas
# 22:18:53	Fim acidentes 			703 acidentes inseridos
# 22:18:56	Fim do processamento do corredor
# ****************************************************************************************************
# 57/167	AV PROF LUIZ IGNACIO DE ANHAIA MELLO
# 22:18:57	Inicio congestionamentos 	31 caminhos
# 22:19:06	Fim congestionamentos 		6213 congestionamentos
# 22:19:06	Inicio acidentes 		630 arestas
# 22:19:06	Fim acidentes 			762 acidentes inseridos
# 22:19:11	Fim do processamento do corredor
# ****************************************************************************************************
# 58/167	AV PROF VICENTE RAO
# 22:19:11	Inicio congestionamentos 	19 caminhos
# 22:19:11	Fim congestionamentos 		89 congestionamentos
# 22:19:11	Inicio acidentes 		568 arestas
# 22:19:11	Fim acidentes 			863 acidentes inseridos
# 22:19:11	Fim do processamento do corredor
# ****************************************************************************************************
# 59/167	AV QUEIROZ FILHO
# 22:19:11	Inicio congestionamentos 	14 caminhos
# 22:19:13	Fim congestionamentos 		3273 congestionamentos
# 22:19:13	Inicio acidentes 		220 arestas
# 22:19:13	Fim acidentes 			545 acidentes inseridos
# 22:19:14	Fim do processamento do corredor
# ****************************************************************************************************
# 60/167	AV RADIAL LESTE-OESTE
# 22:19:14	Inicio congestionamentos 	751 caminhos
# 22:20:20	Fim congestionamentos 		49416 congestionamentos
# 22:20:20	Inicio acidentes 		2609 arestas
# 22:20:20	Fim acidentes 			3105 acidentes inseridos
# 22:20:45	Fim do processamento do corredor
# ****************************************************************************************************
# 61/167	AV RAIMUNDO PEREIRA DE MAGALHAES
# 22:20:46	Inicio congestionamentos 	4 caminhos
# 22:20:46	Fim congestionamentos 		60 congestionamentos
# 22:20:46	Inicio acidentes 		349 arestas
# 22:20:46	Fim acidentes 			946 acidentes inseridos
# 22:20:46	Fim do processamento do corredor
# ****************************************************************************************************
# 62/167	AV RANGEL PESTANA
# 22:20:46	Inicio congestionamentos 	70 caminhos
# 22:20:48	Fim congestionamentos 		2121 congestionamentos
# 22:20:48	Inicio acidentes 		476 arestas
# 22:20:48	Fim acidentes 			193 acidentes inseridos
# 22:20:49	Fim do processamento do corredor
# ****************************************************************************************************
# 63/167	AV REBOUCAS
# 22:20:49	Inicio congestionamentos 	323 caminhos
# 22:21:20	Fim congestionamentos 		27431 congestionamentos
# 22:21:20	Inicio acidentes 		1102 arestas
# 22:21:20	Fim acidentes 			447 acidentes inseridos
# 22:21:33	Fim do processamento do corredor
# ****************************************************************************************************
# 64/167	AV REPUBLICA DO LÍBANO
# 22:21:33	Inicio congestionamentos 	25 caminhos
# 22:21:33	Fim congestionamentos 		234 congestionamentos
# 22:21:33	Inicio acidentes 		541 arestas
# 22:21:33	Fim acidentes 			136 acidentes inseridos
# 22:21:34	Fim do processamento do corredor
# ****************************************************************************************************
# 65/167	AV RICARDO JAFET
# 22:21:34	Inicio congestionamentos 	14 caminhos
# 22:21:34	Fim congestionamentos 		109 congestionamentos
# 22:21:34	Inicio acidentes 		737 arestas
# 22:21:34	Fim acidentes 			582 acidentes inseridos
# 22:21:34	Fim do processamento do corredor
# ****************************************************************************************************
# 66/167	AV RIO BRANCO
# 22:21:34	Inicio congestionamentos 	18 caminhos
# 22:21:35	Fim congestionamentos 		204 congestionamentos
# 22:21:35	Inicio acidentes 		447 arestas
# 22:21:35	Fim acidentes 			473 acidentes inseridos
# 22:21:35	Fim do processamento do corredor
# ****************************************************************************************************
# 67/167	AV ROQUE PETRONI JUNIOR
# 22:21:35	Inicio congestionamentos 	24 caminhos
# 22:21:35	Fim congestionamentos 		308 congestionamentos
# 22:21:35	Inicio acidentes 		331 arestas
# 22:21:35	Fim acidentes 			639 acidentes inseridos
# 22:21:35	Fim do processamento do corredor
# ****************************************************************************************************
# 68/167	AV RUBEM BERTA
# 22:21:35	Inicio congestionamentos 	4 caminhos
# 22:21:36	Fim congestionamentos 		62 congestionamentos
# 22:21:36	Inicio acidentes 		262 arestas
# 22:21:36	Fim acidentes 			110 acidentes inseridos
# 22:21:36	Fim do processamento do corredor
# ****************************************************************************************************
# 69/167	AV RUDGE
# 22:21:36	Inicio congestionamentos 	32 caminhos
# 22:21:37	Fim congestionamentos 		1668 congestionamentos
# 22:21:37	Inicio acidentes 		368 arestas
# 22:21:37	Fim acidentes 			138 acidentes inseridos
# 22:21:37	Fim do processamento do corredor
# ****************************************************************************************************
# 70/167	AV SALIM FARAH MALUF
# 22:21:37	Inicio congestionamentos 	206 caminhos
# 22:22:10	Fim congestionamentos 		29274 congestionamentos
# 22:22:10	Inicio acidentes 		1185 arestas
# 22:22:10	Fim acidentes 			1319 acidentes inseridos
# 22:22:23	Fim do processamento do corredor
# ****************************************************************************************************
# 71/167	AV SANTO AMARO
# 22:22:23	Inicio congestionamentos 	131 caminhos
# 22:22:27	Fim congestionamentos 		1443 congestionamentos
# 22:22:27	Inicio acidentes 		1755 arestas
# 22:22:27	Fim acidentes 			1090 acidentes inseridos
# 22:22:28	Fim do processamento do corredor
# ****************************************************************************************************
# 72/167	AV SEN F1 - TEOTONIO VILELA
# 22:22:28	Inicio congestionamentos 	2 caminhos
# 22:22:28	Fim congestionamentos 		13 congestionamentos
# 22:22:28	Inicio acidentes 		143 arestas
# 22:22:28	Fim acidentes 			128 acidentes inseridos
# 22:22:28	Fim do processamento do corredor
# ****************************************************************************************************
# 73/167	AV SUMARE
# 22:22:28	Inicio congestionamentos 	15 caminhos
# 22:22:29	Fim congestionamentos 		229 congestionamentos
# 22:22:29	Inicio acidentes 		420 arestas
# 22:22:29	Fim acidentes 			249 acidentes inseridos
# 22:22:29	Fim do processamento do corredor
# ****************************************************************************************************
# 74/167	AV SÃO GABRIEL
# 22:22:29	Inicio congestionamentos 	9 caminhos
# 22:22:30	Fim congestionamentos 		787 congestionamentos
# 22:22:30	Inicio acidentes 		299 arestas
# 22:22:30	Fim acidentes 			0 acidentes inseridos
# 22:22:30	Fim do processamento do corredor
# ****************************************************************************************************
# 75/167	AV SÃO JOAO
# 22:22:30	Inicio congestionamentos 	1 caminhos
# 22:22:30	Fim congestionamentos 		4 congestionamentos
# 22:22:30	Inicio acidentes 		174 arestas
# 22:22:30	Fim acidentes 			10 acidentes inseridos
# 22:22:30	Fim do processamento do corredor
# ****************************************************************************************************
# 76/167	AV SÃO VALERIO
# 22:22:30	Inicio congestionamentos 	3 caminhos
# 22:22:30	Fim congestionamentos 		574 congestionamentos
# 22:22:30	Inicio acidentes 		144 arestas
# 22:22:30	Fim acidentes 			46 acidentes inseridos
# 22:22:31	Fim do processamento do corredor
# ****************************************************************************************************
# 77/167	AV VER JOAO DE LUCA
# 22:22:31	Inicio congestionamentos 	9 caminhos
# 22:22:31	Fim congestionamentos 		133 congestionamentos
# 22:22:31	Inicio acidentes 		387 arestas
# 22:22:31	Fim acidentes 			409 acidentes inseridos
# 22:22:31	Fim do processamento do corredor
# ****************************************************************************************************
# 78/167	AV VER JOSE DINIZ
# 22:22:31	Inicio congestionamentos 	54 caminhos
# 22:22:33	Fim congestionamentos 		1060 congestionamentos
# 22:22:33	Inicio acidentes 		910 arestas
# 22:22:33	Fim acidentes 			220 acidentes inseridos
# 22:22:33	Fim do processamento do corredor
# ****************************************************************************************************
# 79/167	AV VINTE E TRES DE MAIO
# 22:22:33	Inicio congestionamentos 	590 caminhos
# 22:25:10	Fim congestionamentos 		53492 congestionamentos
# 22:25:11	Inicio acidentes 		1915 arestas
# 22:25:11	Fim acidentes 			240 acidentes inseridos
# 22:26:27	Fim do processamento do corredor
# ****************************************************************************************************
# 80/167	AV VITAL BRASIL
# 22:26:27	Inicio congestionamentos 	14 caminhos
# 22:26:29	Fim congestionamentos 		1742 congestionamentos
# 22:26:29	Inicio acidentes 		364 arestas
# 22:26:29	Fim acidentes 			62 acidentes inseridos
# 22:26:30	Fim do processamento do corredor
# ****************************************************************************************************
# 81/167	AV VITOR MANZINI
# 22:26:30	Inicio congestionamentos 	9 caminhos
# 22:26:31	Fim congestionamentos 		696 congestionamentos
# 22:26:31	Inicio acidentes 		201 arestas
# 22:26:31	Fim acidentes 			56 acidentes inseridos
# 22:26:32	Fim do processamento do corredor
# ****************************************************************************************************
# 82/167	AV WASHINGTON LUIS
# 22:26:32	Inicio congestionamentos 	315 caminhos
# 22:26:55	Fim congestionamentos 		16964 congestionamentos
# 22:26:55	Inicio acidentes 		1448 arestas
# 22:26:55	Fim acidentes 			989 acidentes inseridos
# 22:27:05	Fim do processamento do corredor
# ****************************************************************************************************
# 83/167	AV. DOM PEDRO I
# 22:27:05	Inicio congestionamentos 	3 caminhos
# 22:27:05	Fim congestionamentos 		10 congestionamentos
# 22:27:05	Inicio acidentes 		341 arestas
# 22:27:05	Fim acidentes 			75 acidentes inseridos
# 22:27:05	Fim do processamento do corredor
# ****************************************************************************************************
# 84/167	AV. EDGAR FACO
# 22:27:05	Inicio congestionamentos 	34 caminhos
# 22:27:10	Fim congestionamentos 		2229 congestionamentos
# 22:27:10	Inicio acidentes 		517 arestas
# 22:27:10	Fim acidentes 			564 acidentes inseridos
# 22:27:12	Fim do processamento do corredor
# ****************************************************************************************************
# 85/167	AV. ENG. CAETANO ALVARES
# 22:27:12	Inicio congestionamentos 	4 caminhos
# 22:27:12	Fim congestionamentos 		11 congestionamentos
# 22:27:12	Inicio acidentes 		811 arestas
# 22:27:12	Fim acidentes 			1107 acidentes inseridos
# 22:27:12	Fim do processamento do corredor
# ****************************************************************************************************
# 86/167	AV. GAL. ATALIBA LEONEL
# 22:27:12	Inicio congestionamentos 	11 caminhos
# 22:27:12	Fim congestionamentos 		130 congestionamentos
# 22:27:12	Inicio acidentes 		321 arestas
# 22:27:12	Fim acidentes 			722 acidentes inseridos
# 22:27:12	Fim do processamento do corredor
# ****************************************************************************************************
# 87/167	AV. SEN. QUEIROZ
# 22:27:12	Inicio congestionamentos 	17 caminhos
# 22:27:15	Fim congestionamentos 		2324 congestionamentos
# 22:27:15	Inicio acidentes 		431 arestas
# 22:27:15	Fim acidentes 			421 acidentes inseridos
# 22:27:16	Fim do processamento do corredor
# ****************************************************************************************************
# 88/167	AV. SÃO LUIS
# 22:27:16	Inicio congestionamentos 	2 caminhos
# 22:27:16	Fim congestionamentos 		270 congestionamentos
# 22:27:16	Inicio acidentes 		183 arestas
# 22:27:16	Fim acidentes 			3 acidentes inseridos
# 22:27:16	Fim do processamento do corredor
# ****************************************************************************************************
# 89/167	BR DO RIO BRANCO
# 22:27:16	Inicio congestionamentos 	4 caminhos
# 22:27:16	Fim congestionamentos 		46 congestionamentos
# 22:27:16	Inicio acidentes 		247 arestas
# 22:27:16	Fim acidentes 			3 acidentes inseridos
# 22:27:16	Fim do processamento do corredor
# ****************************************************************************************************
# 90/167	CV AYRTON SENNA
# 22:27:16	Inicio congestionamentos 	14 caminhos
# 22:27:22	Fim congestionamentos 		8029 congestionamentos
# 22:27:22	Inicio acidentes 		339 arestas
# 22:27:22	Fim acidentes 			0 acidentes inseridos
# 22:27:26	Fim do processamento do corredor
# ****************************************************************************************************
# 91/167	CV MARIA MALUF
# 22:27:26	Inicio congestionamentos 	18 caminhos
# 22:27:28	Fim congestionamentos 		1412 congestionamentos
# 22:27:28	Inicio acidentes 		295 arestas
# 22:27:28	Fim acidentes 			119 acidentes inseridos
# 22:27:29	Fim do processamento do corredor
# ****************************************************************************************************
# 92/167	CV TRIBUNAL DE JUSTICA DO E. SP
# 22:27:29	Inicio congestionamentos 	7 caminhos
# 22:27:45	Fim congestionamentos 		12850 congestionamentos
# 22:27:45	Inicio acidentes 		260 arestas
# 22:27:45	Fim acidentes 			0 acidentes inseridos
# 22:27:53	Fim do processamento do corredor
# ****************************************************************************************************
# 93/167	ELEV PRES JOAO GOULART
# 22:27:53	Inicio congestionamentos 	73 caminhos
# 22:27:59	Fim congestionamentos 		3708 congestionamentos
# 22:27:59	Inicio acidentes 		595 arestas
# 22:27:59	Fim acidentes 			168 acidentes inseridos
# 22:28:01	Fim do processamento do corredor
# ****************************************************************************************************
# 94/167	EST DE ITAPECERICA
# 22:28:01	Inicio congestionamentos 	78 caminhos
# 22:28:06	Fim congestionamentos 		4063 congestionamentos
# 22:28:06	Inicio acidentes 		513 arestas
# 22:28:06	Fim acidentes 			368 acidentes inseridos
# 22:28:08	Fim do processamento do corredor
# ****************************************************************************************************
# 95/167	MARGINAL PINHEIROS CBINT
# 22:28:08	Inicio congestionamentos 	1045 caminhos
# 22:30:48	Fim congestionamentos 		86801 congestionamentos
# 22:30:48	Inicio acidentes 		2878 arestas
# 22:30:48	Fim acidentes 			2198 acidentes inseridos
# 22:32:14	Fim do processamento do corredor
# ****************************************************************************************************
# 96/167	MARGINAL TIETE CBAS CENTRAL
# 22:32:14	Inicio congestionamentos 	1554 caminhos
# 22:36:23	Fim congestionamentos 		117125 congestionamentos
# 22:36:23	Inicio acidentes 		2863 arestas
# 22:36:23	Fim acidentes 			4597 acidentes inseridos
# 22:38:35	Fim do processamento do corredor
# ****************************************************************************************************
# 97/167	MAX FEFFER TUNEL (CIDADE JARDIM)
# 22:38:35	Inicio congestionamentos 	13 caminhos
# 22:38:43	Fim congestionamentos 		12032 congestionamentos
# 22:38:43	Inicio acidentes 		306 arestas
# 22:38:43	Fim acidentes 			0 acidentes inseridos
# 22:38:47	Fim do processamento do corredor
# ****************************************************************************************************
# 98/167	MIGUEL ESTEFANO,VD
# 22:38:47	Inicio congestionamentos 	1 caminhos
# 22:38:47	Fim congestionamentos 		16 congestionamentos
# 22:38:47	Inicio acidentes 		29 arestas
# 22:38:47	Fim acidentes 			67 acidentes inseridos
# 22:38:47	Fim do processamento do corredor
# ****************************************************************************************************
# 99/167	PQ ANHANGABAU
# 22:38:47	Inicio congestionamentos 	378 caminhos
# 22:39:54	Fim congestionamentos 		38338 congestionamentos
# 22:39:54	Inicio acidentes 		1236 arestas
# 22:39:54	Fim acidentes 			311 acidentes inseridos
# 22:40:27	Fim do processamento do corredor
# ****************************************************************************************************
# 100/167	PQ DOM PEDRO II
# 22:40:27	Inicio congestionamentos 	1 caminhos
# 22:40:27	Fim congestionamentos 		7 congestionamentos
# 22:40:27	Inicio acidentes 		118 arestas
# 22:40:27	Fim acidentes 			0 acidentes inseridos
# 22:40:27	Fim do processamento do corredor
# ****************************************************************************************************
# 101/167	PRES. PTE (VILA MARIA) JANIO QUADROS
# 22:40:27	Inicio congestionamentos 	4 caminhos
# 22:40:27	Fim congestionamentos 		653 congestionamentos
# 22:40:27	Inicio acidentes 		83 arestas
# 22:40:27	Fim acidentes 			0 acidentes inseridos
# 22:40:28	Fim do processamento do corredor
# ****************************************************************************************************
# 102/167	PT E AV CRUZEIRO DO SUL
# 22:40:28	Inicio congestionamentos 	79 caminhos
# 22:40:34	Fim congestionamentos 		5106 congestionamentos
# 22:40:34	Inicio acidentes 		774 arestas
# 22:40:34	Fim acidentes 			197 acidentes inseridos
# 22:40:37	Fim do processamento do corredor
# ****************************************************************************************************
# 103/167	PTE ATILIO FONTANA
# 22:40:37	Inicio congestionamentos 	3 caminhos
# 22:40:39	Fim congestionamentos 		9720 congestionamentos
# 22:40:39	Inicio acidentes 		150 arestas
# 22:40:39	Fim acidentes 			159 acidentes inseridos
# 22:40:41	Fim do processamento do corredor
# ****************************************************************************************************
# 104/167	PTE BERNARDO GOLDFARB
# 22:40:41	Inicio congestionamentos 	3 caminhos
# 22:40:41	Fim congestionamentos 		21 congestionamentos
# 22:40:41	Inicio acidentes 		165 arestas
# 22:40:41	Fim acidentes 			0 acidentes inseridos
# 22:40:41	Fim do processamento do corredor
# ****************************************************************************************************
# 105/167	PTE CIDADE UNIVERSITARIA - PREFEITO WILLIAM SALEM
# 22:40:41	Inicio congestionamentos 	4 caminhos
# 22:40:42	Fim congestionamentos 		6257 congestionamentos
# 22:40:42	Inicio acidentes 		114 arestas
# 22:40:42	Fim acidentes 			31 acidentes inseridos
# 22:40:43	Fim do processamento do corredor
# ****************************************************************************************************
# 106/167	PTE DA VILA GUILHERME C W O BAUMGART
# 22:40:43	Inicio congestionamentos 	2 caminhos
# 22:40:43	Fim congestionamentos 		490 congestionamentos
# 22:40:43	Inicio acidentes 		99 arestas
# 22:40:43	Fim acidentes 			0 acidentes inseridos
# 22:40:43	Fim do processamento do corredor
# ****************************************************************************************************
# 107/167	PTE DO LIMAO-ADHEMAR F. DA SILVA
# 22:40:43	Inicio congestionamentos 	35 caminhos
# 22:40:46	Fim congestionamentos 		5057 congestionamentos
# 22:40:46	Inicio acidentes 		272 arestas
# 22:40:46	Fim acidentes 			36 acidentes inseridos
# 22:40:47	Fim do processamento do corredor
# ****************************************************************************************************
# 108/167	PTE DO PIQUERI JOELMIR BETING
# 22:40:47	Inicio congestionamentos 	2 caminhos
# 22:40:48	Fim congestionamentos 		3566 congestionamentos
# 22:40:48	Inicio acidentes 		78 arestas
# 22:40:48	Fim acidentes 			0 acidentes inseridos
# 22:40:49	Fim do processamento do corredor
# ****************************************************************************************************
# 109/167	PTE DOS REMEDIOS-CARMEN F. NEVES
# 22:40:49	Inicio congestionamentos 	2 caminhos
# 22:40:49	Fim congestionamentos 		2241 congestionamentos
# 22:40:49	Inicio acidentes 		79 arestas
# 22:40:49	Fim acidentes 			0 acidentes inseridos
# 22:40:50	Fim do processamento do corredor
# ****************************************************************************************************
# 110/167	PTE ENG ARY TORRES
# 22:40:50	Inicio congestionamentos 	7 caminhos
# 22:40:52	Fim congestionamentos 		2389 congestionamentos
# 22:40:52	Inicio acidentes 		152 arestas
# 22:40:52	Fim acidentes 			0 acidentes inseridos
# 22:40:54	Fim do processamento do corredor
# ****************************************************************************************************
# 111/167	PTE FREGUESIA DO O P N RODRIGUES
# 22:40:54	Inicio congestionamentos 	2 caminhos
# 22:40:54	Fim congestionamentos 		1126 congestionamentos
# 22:40:54	Inicio acidentes 		63 arestas
# 22:40:54	Fim acidentes 			0 acidentes inseridos
# 22:40:54	Fim do processamento do corredor
# ****************************************************************************************************
# 112/167	PTE SANTO DIAS DA SILVA A
# 22:40:54	Inicio congestionamentos 	6 caminhos
# 22:40:57	Fim congestionamentos 		3538 congestionamentos
# 22:40:57	Inicio acidentes 		114 arestas
# 22:40:57	Fim acidentes 			0 acidentes inseridos
# 22:40:58	Fim do processamento do corredor
# ****************************************************************************************************
# 113/167	PTE TRANSAMERICA
# 22:40:58	Inicio congestionamentos 	4 caminhos
# 22:41:01	Fim congestionamentos 		2687 congestionamentos
# 22:41:01	Inicio acidentes 		81 arestas
# 22:41:01	Fim acidentes 			0 acidentes inseridos
# 22:41:02	Fim do processamento do corredor
# ****************************************************************************************************
# 114/167	PÇA DA SE
# 22:41:02	Inicio congestionamentos 	4 caminhos
# 22:41:02	Fim congestionamentos 		242 congestionamentos
# 22:41:02	Inicio acidentes 		95 arestas
# 22:41:02	Fim acidentes 			20 acidentes inseridos
# 22:41:02	Fim do processamento do corredor
# ****************************************************************************************************
# 115/167	PÇA JOAO MENDES
# 22:41:02	Inicio congestionamentos 	1 caminhos
# 22:41:03	Fim congestionamentos 		249 congestionamentos
# 22:41:03	Inicio acidentes 		145 arestas
# 22:41:03	Fim acidentes 			0 acidentes inseridos
# 22:41:03	Fim do processamento do corredor
# ****************************************************************************************************
# 116/167	R ALVARENGA
# 22:41:03	Inicio congestionamentos 	9 caminhos
# 22:41:03	Fim congestionamentos 		79 congestionamentos
# 22:41:03	Inicio acidentes 		389 arestas
# 22:41:03	Fim acidentes 			17 acidentes inseridos
# 22:41:03	Fim do processamento do corredor
# ****************************************************************************************************
# 117/167	R BUTANTA
# 22:41:03	Inicio congestionamentos 	7 caminhos
# 22:41:03	Fim congestionamentos 		192 congestionamentos
# 22:41:03	Inicio acidentes 		201 arestas
# 22:41:03	Fim acidentes 			1 acidentes inseridos
# 22:41:03	Fim do processamento do corredor
# ****************************************************************************************************
# 118/167	R CAMARGO
# 22:41:03	Inicio congestionamentos 	15 caminhos
# 22:41:04	Fim congestionamentos 		400 congestionamentos
# 22:41:04	Inicio acidentes 		280 arestas
# 22:41:04	Fim acidentes 			0 acidentes inseridos
# 22:41:04	Fim do processamento do corredor
# ****************************************************************************************************
# 119/167	R CAP PACHECO E CHAVES
# 22:41:04	Inicio congestionamentos 	2 caminhos
# 22:41:04	Fim congestionamentos 		21 congestionamentos
# 22:41:04	Inicio acidentes 		240 arestas
# 22:41:04	Fim acidentes 			92 acidentes inseridos
# 22:41:04	Fim do processamento do corredor
# ****************************************************************************************************
# 120/167	R CARD ARCOVERDE
# 22:41:04	Inicio congestionamentos 	26 caminhos
# 22:41:05	Fim congestionamentos 		201 congestionamentos
# 22:41:05	Inicio acidentes 		709 arestas
# 22:41:05	Fim acidentes 			163 acidentes inseridos
# 22:41:05	Fim do processamento do corredor
# ****************************************************************************************************
# 121/167	R CLELIA
# 22:41:05	Inicio congestionamentos 	22 caminhos
# 22:41:05	Fim congestionamentos 		408 congestionamentos
# 22:41:05	Inicio acidentes 		496 arestas
# 22:41:05	Fim acidentes 			573 acidentes inseridos
# 22:41:05	Fim do processamento do corredor
# ****************************************************************************************************
# 122/167	R DA CONSOLACAO
# 22:41:05	Inicio congestionamentos 	153 caminhos
# 22:41:10	Fim congestionamentos 		4082 congestionamentos
# 22:41:10	Inicio acidentes 		937 arestas
# 22:41:10	Fim acidentes 			46 acidentes inseridos
# 22:41:11	Fim do processamento do corredor
# ****************************************************************************************************
# 123/167	R DA FIGUEIRA
# 22:41:11	Inicio congestionamentos 	2 caminhos
# 22:41:11	Fim congestionamentos 		150 congestionamentos
# 22:41:11	Inicio acidentes 		170 arestas
# 22:41:11	Fim acidentes 			0 acidentes inseridos
# 22:41:11	Fim do processamento do corredor
# ****************************************************************************************************
# 124/167	R DAS JUNTAS PROVISORIAS
# 22:41:11	Inicio congestionamentos 	32 caminhos
# 22:41:13	Fim congestionamentos 		714 congestionamentos
# 22:41:13	Inicio acidentes 		586 arestas
# 22:41:13	Fim acidentes 			435 acidentes inseridos
# 22:41:14	Fim do processamento do corredor
# ****************************************************************************************************
# 125/167	R DIANOPOLIS
# 22:41:14	Inicio congestionamentos 	2 caminhos
# 22:41:14	Fim congestionamentos 		46 congestionamentos
# 22:41:14	Inicio acidentes 		160 arestas
# 22:41:14	Fim acidentes 			21 acidentes inseridos
# 22:41:14	Fim do processamento do corredor
# ****************************************************************************************************
# 126/167	R E VD GASOMETRO
# 22:41:14	Inicio congestionamentos 	7 caminhos
# 22:41:14	Fim congestionamentos 		166 congestionamentos
# 22:41:14	Inicio acidentes 		254 arestas
# 22:41:14	Fim acidentes 			0 acidentes inseridos
# 22:41:14	Fim do processamento do corredor
# ****************************************************************************************************
# 127/167	R ENG OSCAR AMERICANO
# 22:41:14	Inicio congestionamentos 	12 caminhos
# 22:41:15	Fim congestionamentos 		295 congestionamentos
# 22:41:15	Inicio acidentes 		257 arestas
# 22:41:15	Fim acidentes 			53 acidentes inseridos
# 22:41:15	Fim do processamento do corredor
# ****************************************************************************************************
# 128/167	R ESTELA
# 22:41:15	Inicio congestionamentos 	5 caminhos
# 22:41:15	Fim congestionamentos 		236 congestionamentos
# 22:41:15	Inicio acidentes 		219 arestas
# 22:41:15	Fim acidentes 			0 acidentes inseridos
# 22:41:15	Fim do processamento do corredor
# ****************************************************************************************************
# 129/167	R GROENLANDIA
# 22:41:15	Inicio congestionamentos 	1 caminhos
# 22:41:15	Fim congestionamentos 		27 congestionamentos
# 22:41:15	Inicio acidentes 		208 arestas
# 22:41:15	Fim acidentes 			0 acidentes inseridos
# 22:41:15	Fim do processamento do corredor
# ****************************************************************************************************
# 130/167	R GUAICURUS
# 22:41:15	Inicio congestionamentos 	19 caminhos
# 22:41:16	Fim congestionamentos 		253 congestionamentos
# 22:41:16	Inicio acidentes 		322 arestas
# 22:41:16	Fim acidentes 			40 acidentes inseridos
# 22:41:16	Fim do processamento do corredor
# ****************************************************************************************************
# 131/167	R HEITOR PENTEADO
# 22:41:16	Inicio congestionamentos 	22 caminhos
# 22:41:16	Fim congestionamentos 		355 congestionamentos
# 22:41:16	Inicio acidentes 		585 arestas
# 22:41:16	Fim acidentes 			366 acidentes inseridos
# 22:41:17	Fim do processamento do corredor
# ****************************************************************************************************
# 132/167	R IBITIRAMA
# 22:41:17	Inicio congestionamentos 	1 caminhos
# 22:41:17	Fim congestionamentos 		56 congestionamentos
# 22:41:17	Inicio acidentes 		242 arestas
# 22:41:17	Fim acidentes 			114 acidentes inseridos
# 22:41:17	Fim do processamento do corredor
# ****************************************************************************************************
# 133/167	R IGUATEMI
# 22:41:17	Inicio congestionamentos 	1 caminhos
# 22:41:17	Fim congestionamentos 		15 congestionamentos
# 22:41:17	Inicio acidentes 		155 arestas
# 22:41:17	Fim acidentes 			0 acidentes inseridos
# 22:41:17	Fim do processamento do corredor
# ****************************************************************************************************
# 134/167	R JOSE FELIX
# 22:41:17	Inicio congestionamentos 	1 caminhos
# 22:41:17	Fim congestionamentos 		262 congestionamentos
# 22:41:17	Inicio acidentes 		78 arestas
# 22:41:17	Fim acidentes 			0 acidentes inseridos
# 22:41:17	Fim do processamento do corredor
# ****************************************************************************************************
# 135/167	R M.M.D.C
# 22:41:17	Inicio congestionamentos 	5 caminhos
# 22:41:18	Fim congestionamentos 		886 congestionamentos
# 22:41:18	Inicio acidentes 		166 arestas
# 22:41:18	Fim acidentes 			0 acidentes inseridos
# 22:41:18	Fim do processamento do corredor
# ****************************************************************************************************
# 136/167	R MANUEL DE TEFFE
# 22:41:18	Inicio congestionamentos 	1 caminhos
# 22:41:18	Fim congestionamentos 		58 congestionamentos
# 22:41:18	Inicio acidentes 		97 arestas
# 22:41:18	Fim acidentes 			26 acidentes inseridos
# 22:41:18	Fim do processamento do corredor
# ****************************************************************************************************
# 137/167	R MELO PEIXOTO
# 22:41:18	Inicio congestionamentos 	18 caminhos
# 22:41:19	Fim congestionamentos 		123 congestionamentos
# 22:41:19	Inicio acidentes 		356 arestas
# 22:41:19	Fim acidentes 			6 acidentes inseridos
# 22:41:19	Fim do processamento do corredor
# ****************************************************************************************************
# 138/167	R REACAO
# 22:41:19	Inicio congestionamentos 	2 caminhos
# 22:41:19	Fim congestionamentos 		74 congestionamentos
# 22:41:19	Inicio acidentes 		96 arestas
# 22:41:19	Fim acidentes 			0 acidentes inseridos
# 22:41:19	Fim do processamento do corredor
# ****************************************************************************************************
# 139/167	R SAPETUBA
# 22:41:19	Inicio congestionamentos 	15 caminhos
# 22:41:20	Fim congestionamentos 		2543 congestionamentos
# 22:41:20	Inicio acidentes 		230 arestas
# 22:41:20	Fim acidentes 			17 acidentes inseridos
# 22:41:21	Fim do processamento do corredor
# ****************************************************************************************************
# 140/167	R TABAPUA
# 22:41:21	Inicio congestionamentos 	4 caminhos
# 22:41:21	Fim congestionamentos 		32 congestionamentos
# 22:41:21	Inicio acidentes 		383 arestas
# 22:41:21	Fim acidentes 			0 acidentes inseridos
# 22:41:21	Fim do processamento do corredor
# ****************************************************************************************************
# 141/167	R TEODORO SAMPAIO
# 22:41:21	Inicio congestionamentos 	53 caminhos
# 22:41:23	Fim congestionamentos 		658 congestionamentos
# 22:41:23	Inicio acidentes 		812 arestas
# 22:41:23	Fim acidentes 			0 acidentes inseridos
# 22:41:23	Fim do processamento do corredor
# ****************************************************************************************************
# 142/167	R5 MARIA PAULA
# 22:41:23	Inicio congestionamentos 	17 caminhos
# 22:41:24	Fim congestionamentos 		2546 congestionamentos
# 22:41:24	Inicio acidentes 		300 arestas
# 22:41:24	Fim acidentes 			1 acidentes inseridos
# 22:41:25	Fim do processamento do corredor
# ****************************************************************************************************
# 143/167	TUNEL JORNALISTA FERNANDO VIEIRA DE MELLO
# 22:41:25	Inicio congestionamentos 	10 caminhos
# 22:41:27	Fim congestionamentos 		10971 congestionamentos
# 22:41:27	Inicio acidentes 		166 arestas
# 22:41:27	Fim acidentes 			0 acidentes inseridos
# 22:41:27	Fim do processamento do corredor
# ****************************************************************************************************
# 144/167	TÚNEL JANIO QUADROS
# 22:41:27	Inicio congestionamentos 	4 caminhos
# 22:41:28	Fim congestionamentos 		2814 congestionamentos
# 22:41:28	Inicio acidentes 		119 arestas
# 22:41:28	Fim acidentes 			0 acidentes inseridos
# 22:41:29	Fim do processamento do corredor
# ****************************************************************************************************
# 145/167	TÚNEL SEBASTIAO CAMARGO
# 22:41:29	Inicio congestionamentos 	4 caminhos
# 22:41:30	Fim congestionamentos 		2971 congestionamentos
# 22:41:30	Inicio acidentes 		213 arestas
# 22:41:30	Fim acidentes 			0 acidentes inseridos
# 22:41:31	Fim do processamento do corredor
# ****************************************************************************************************
# 146/167	VD ANTARTICA
# 22:41:31	Inicio congestionamentos 	10 caminhos
# 22:41:33	Fim congestionamentos 		1703 congestionamentos
# 22:41:33	Inicio acidentes 		228 arestas
# 22:41:33	Fim acidentes 			0 acidentes inseridos
# 22:41:33	Fim do processamento do corredor
# ****************************************************************************************************
# 147/167	VD ANTONIO NAKASHIMA
# 22:41:33	Inicio congestionamentos 	2 caminhos
# 22:41:33	Fim congestionamentos 		338 congestionamentos
# 22:41:33	Inicio acidentes 		149 arestas
# 22:41:33	Fim acidentes 			0 acidentes inseridos
# 22:41:33	Fim do processamento do corredor
# ****************************************************************************************************
# 148/167	VD CAP PACHECO E CHAVES
# 22:41:34	Inicio congestionamentos 	2 caminhos
# 22:41:34	Fim congestionamentos 		90 congestionamentos
# 22:41:34	Inicio acidentes 		179 arestas
# 22:41:34	Fim acidentes 			18 acidentes inseridos
# 22:41:34	Fim do processamento do corredor
# ****************************************************************************************************
# 149/167	VD COMEN ELIAS NAGIB BREIM
# 22:41:34	Inicio congestionamentos 	4 caminhos
# 22:41:35	Fim congestionamentos 		2875 congestionamentos
# 22:41:35	Inicio acidentes 		157 arestas
# 22:41:35	Fim acidentes 			1 acidentes inseridos
# 22:41:35	Fim do processamento do corredor
# ****************************************************************************************************
# 150/167	VD DIARIO POPULAR
# 22:41:35	Inicio congestionamentos 	3 caminhos
# 22:41:35	Fim congestionamentos 		74 congestionamentos
# 22:41:35	Inicio acidentes 		137 arestas
# 22:41:35	Fim acidentes 			0 acidentes inseridos
# 22:41:35	Fim do processamento do corredor
# ****************************************************************************************************
# 151/167	VD DONA PAULINA
# 22:41:35	Inicio congestionamentos 	3 caminhos
# 22:41:37	Fim congestionamentos 		2626 congestionamentos
# 22:41:37	Inicio acidentes 		150 arestas
# 22:41:37	Fim acidentes 			0 acidentes inseridos
# 22:41:38	Fim do processamento do corredor
# ****************************************************************************************************
# 152/167	VD DR MANUEL JOSE CHAVES
# 22:41:38	Inicio congestionamentos 	2 caminhos
# 22:41:41	Fim congestionamentos 		3158 congestionamentos
# 22:41:41	Inicio acidentes 		178 arestas
# 22:41:41	Fim acidentes 			0 acidentes inseridos
# 22:41:43	Fim do processamento do corredor
# ****************************************************************************************************
# 153/167	VD EUSEBIO STEVAUX
# 22:41:43	Inicio congestionamentos 	3 caminhos
# 22:41:44	Fim congestionamentos 		1770 congestionamentos
# 22:41:44	Inicio acidentes 		196 arestas
# 22:41:44	Fim acidentes 			0 acidentes inseridos
# 22:41:45	Fim do processamento do corredor
# ****************************************************************************************************
# 154/167	VD GAZETA DO IPIRANGA
# 22:41:45	Inicio congestionamentos 	2 caminhos
# 22:41:45	Fim congestionamentos 		84 congestionamentos
# 22:41:45	Inicio acidentes 		153 arestas
# 22:41:45	Fim acidentes 			0 acidentes inseridos
# 22:41:45	Fim do processamento do corredor
# ****************************************************************************************************
# 155/167	VD GRANDE SAO PAULO VER M O SALA
# 22:41:45	Inicio congestionamentos 	3 caminhos
# 22:41:47	Fim congestionamentos 		1305 congestionamentos
# 22:41:47	Inicio acidentes 		212 arestas
# 22:41:47	Fim acidentes 			0 acidentes inseridos
# 22:41:48	Fim do processamento do corredor
# ****************************************************************************************************
# 156/167	VD GUADALAJARA-JOAO BEHISNELIAN
# 22:41:48	Inicio congestionamentos 	4 caminhos
# 22:41:48	Fim congestionamentos 		44 congestionamentos
# 22:41:48	Inicio acidentes 		166 arestas
# 22:41:48	Fim acidentes 			9 acidentes inseridos
# 22:41:48	Fim do processamento do corredor
# ****************************************************************************************************
# 157/167	VD JOAO JORGE SAAD
# 22:41:48	Inicio congestionamentos 	1 caminhos
# 22:41:48	Fim congestionamentos 		107 congestionamentos
# 22:41:48	Inicio acidentes 		192 arestas
# 22:41:48	Fim acidentes 			7 acidentes inseridos
# 22:41:48	Fim do processamento do corredor
# ****************************************************************************************************
# 158/167	VD JOSE COLASSUONO
# 22:41:48	Inicio congestionamentos 	1 caminhos
# 22:41:48	Fim congestionamentos 		5 congestionamentos
# 22:41:48	Inicio acidentes 		141 arestas
# 22:41:48	Fim acidentes 			0 acidentes inseridos
# 22:41:48	Fim do processamento do corredor
# ****************************************************************************************************
# 159/167	VD MIN ALIOMAR BALEEIRO
# 22:41:49	Inicio congestionamentos 	2 caminhos
# 22:41:49	Fim congestionamentos 		1835 congestionamentos
# 22:41:49	Inicio acidentes 		104 arestas
# 22:41:49	Fim acidentes 			0 acidentes inseridos
# 22:41:49	Fim do processamento do corredor
# ****************************************************************************************************
# 160/167	VD POMPEIA MISSIONARIO MANOEL DE
# 22:41:49	Inicio congestionamentos 	6 caminhos
# 22:41:51	Fim congestionamentos 		4873 congestionamentos
# 22:41:51	Inicio acidentes 		150 arestas
# 22:41:51	Fim acidentes 			0 acidentes inseridos
# 22:41:52	Fim do processamento do corredor
# ****************************************************************************************************
# 161/167	VD REPUBLICA DA ARMENIA
# 22:41:52	Inicio congestionamentos 	4 caminhos
# 22:42:02	Fim congestionamentos 		7167 congestionamentos
# 22:42:02	Inicio acidentes 		235 arestas
# 22:42:02	Fim acidentes 			0 acidentes inseridos
# 22:42:07	Fim do processamento do corredor
# ****************************************************************************************************
# 162/167	VD ROBERTO ABREU SODRE
# 22:42:07	Inicio congestionamentos 	1 caminhos
# 22:42:08	Fim congestionamentos 		276 congestionamentos
# 22:42:08	Inicio acidentes 		135 arestas
# 22:42:08	Fim acidentes 			0 acidentes inseridos
# 22:42:08	Fim do processamento do corredor
# ****************************************************************************************************
# 163/167	VD VILA MATILDE
# 22:42:08	Inicio congestionamentos 	1 caminhos
# 22:42:08	Fim congestionamentos 		22 congestionamentos
# 22:42:08	Inicio acidentes 		30 arestas
# 22:42:08	Fim acidentes 			0 acidentes inseridos
# 22:42:08	Fim do processamento do corredor
# ****************************************************************************************************
# 164/167	VD VINTE E CINCO DE MARCO
# 22:42:08	Inicio congestionamentos 	1 caminhos
# 22:42:08	Fim congestionamentos 		11 congestionamentos
# 22:42:08	Inicio acidentes 		113 arestas
# 22:42:08	Fim acidentes 			0 acidentes inseridos
# 22:42:08	Fim do processamento do corredor
# ****************************************************************************************************
# 165/167	VIA ANCHIETA
# 22:42:08	Inicio congestionamentos 	39 caminhos
# 22:42:10	Fim congestionamentos 		2465 congestionamentos
# 22:42:10	Inicio acidentes 		447 arestas
# 22:42:10	Fim acidentes 			437 acidentes inseridos
# 22:42:11	Fim do processamento do corredor
# ****************************************************************************************************
# 166/167	VIA RAPOSO TAVARES
# 22:42:11	Inicio congestionamentos 	12 caminhos
# 22:42:16	Fim congestionamentos 		3252 congestionamentos
# 22:42:16	Inicio acidentes 		334 arestas
# 22:42:16	Fim acidentes 			51 acidentes inseridos
# 22:42:18	Fim do processamento do corredor

# %% [markdown]
# #### Conferindo quais acidentes ficaram dentro e fora do perímetro dos acidentes

# %%
m = folium.Map(
        zoom_start=12,location=(-23.6, -46.6), tiles="cartodb positron")    

n = len(df_acidentes)
qtde_inseridos = 0
i = 0
last_checkpoint = 0

for _, a in df_acidentes.iterrows():

    i += 1
    if i / n > last_checkpoint:
        print('{}\t{}% \t\t({}/{})'.format(datetime.now().strftime('%H:%M:%S'),
                                            int(last_checkpoint * 100), i, n))
        last_checkpoint += .33
            
    #plota acidente
    v_a = (float(a['latitude'].replace(',','.')), float(a['longitude'].replace(',','.')))
    
    if a['index'] in acidentes_inseridos:
        qtde_inseridos += 1
        c = 'blue'
    else: c = 'red'


    folium.Circle(
        location = v_a,
        radius = 1,
        color = c,
        weight = 1
    ).add_to(m)
    
print('{}\t\tSalvando mapa em html (5 min)'.format(datetime.now().strftime('%H:%M:%S')))
m.save('mapas/acidentes_congestionamentos.html')

print('{}\t\tFim do Processamento'.format(datetime.now().strftime('%H:%M:%S')))

print('')
print('Total de Acidentes de São Paulo: ', n)
print('Acidentes Considerados no Estudo: ', qtde_inseridos)
# Out:
# 22:42:25	0% 		(1/216010)
# 22:42:33	33% 		(71284/216010)
# 22:42:42	66% 		(142567/216010)
# 22:42:51	99% 		(213850/216010)
# 22:42:51		Salvando mapa em html (5 min)
# 22:45:07		Fim do Processamento
#
# Total de Acidentes de São Paulo:  216010
# Acidentes Considerados no Estudo:  82774

# %% [markdown]
# #### Unindo os csvs

# %%
print('{}\tIniciando leitura das bases de cada corredor (1 min)'.format(datetime.now().strftime('%H:%M:%S')))

dfs = []

for S in subgraphs:
    c = S.split('/')[0]
    
    aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
    dfs.append(aux)

# Concatenar todos os dataframes em um único dataframe
df_arestas = pd.concat(dfs, ignore_index=True)

print('{}\tFim da leitura das bases: {} registros'.format(datetime.now().strftime('%H:%M:%S'), len(df_arestas)))
# 5363089 
# 5349918
# Out:
# 22:51:25	Iniciando leitura das bases de cada corredor (1 min)
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:8: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   aux = pd.read_csv('data/arestas/arestas_' + c + '.csv')
# 22:51:42	Fim da leitura das bases: 5349918 registros
# C:\Users\gigec\AppData\Local\Temp\ipykernel_3984\3918083833.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_arestas = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# #### Regulação do campo de data e hora

# %%
n = len(df_arestas)

def separa_hora(h):
    if type(h) != str:
        return None
    s = h.split(':')
    if len(s) >= 2:
        return s[0].zfill(2)
    return None

def separa_minuto(h):
    if type(h) != str:
        return None
    s = h.split(':')
    if len(s) >= 2:
        return s[1].zfill(2)
    return None

print(f'{datetime.now().strftime("%H:%M:%S")}\tIniciando conversão dos campos de horario (1 min)')

df_arestas['hora_valor'] = df_arestas['hora'].apply(separa_hora)
df_arestas['minuto_valor'] = df_arestas['hora'].apply(separa_minuto)

df_arestas.dropna(subset=['hora_valor'], inplace = True)
df_arestas.dropna(subset=['minuto_valor'], inplace = True)

print(f'{datetime.now().strftime("%H:%M:%S")}\tFim processamento')
print(f'{n - len(df_arestas)} registros deletados (sem dados de horario)') # 157
# Out:
# 22:51:42	Iniciando conversão dos campos de horario (1 min)
# 22:51:52	Fim processamento
# 157 registros deletados (sem dados de horario)

# %%
n = len(df_arestas)

def separa_dia(d):
    if type(d) != str:
        return None
    sep = '/' if '/' in d else '-'
    s = d.split(sep)
    if len(s) < 2:
        return None
    
    if len(s[0]) == 4:
        return s[2].zfill(2)
    
    return s[0].zfill(2)

def separa_mes(d):
    if type(d) != str:
        return None
    sep = '/' if '/' in d else '-'
    s = d.split(sep)
    if len(s) < 2:
        return None
    return s[1].zfill(2)

def separa_ano(d):
    if type(d) != str:
        return None
    sep = '/' if '/' in d else '-'
    s = d.split(sep)
    if len(s) < 2:
        return None
    
    if len(s[0]) == 4:
        return s[0]
    
    if len(s[2]) == 2:
        return '20' + s[2]
    if len(s[2]) == 4:
        return s[2]
    return None

print(f'{datetime.now().strftime("%H:%M:%S")}\tIniciando conversão dos campos de data (1 min)')

df_arestas['dia_valor'] = df_arestas['data'].apply(separa_dia)
df_arestas['mes_valor'] = df_arestas['data'].apply(separa_mes)
df_arestas['ano_valor'] = df_arestas['data'].apply(separa_ano)

df_arestas.dropna(subset=['dia_valor'], inplace = True)
df_arestas.dropna(subset=['mes_valor'], inplace = True)
df_arestas.dropna(subset=['ano_valor'], inplace = True)

print(f'{datetime.now().strftime("%H:%M:%S")}\tFim processamento')
print(f'{n - len(df_arestas)} registros deletados (com data inconsistente)') # 0
# Out:
# 22:51:52	Iniciando conversão dos campos de data (1 min)
# 22:52:15	Fim processamento
# 0 registros deletados (com data inconsistente)

# %%
df_arestas.sample(5)
# Out:
#         Unnamed: 0                         vertice_a  \
# 3336118     105617  (-46.5805595999, -23.5412749664)
# 1890585     123561  (-46.6799119503, -23.6543632335)
# 669385      286164  (-46.6268520693, -23.5426967087)
# 3699239      57530  (-46.6627815239, -23.6230539469)
# 44687        43770  (-46.7009710875, -23.6961568606)
#
#                                 vertice_b  \
# 3336118  (-46.5804399899, -23.5416930341)
# 1890585   (-46.6799457119, -23.653977671)
# 669385   (-46.6268501114, -23.5418705708)
# 3699239  (-46.6638688985, -23.6231362424)
# 44687    (-46.7000314232, -23.6958558424)
#
#                                                   geometry     index  \
# 3336118  LINESTRING (-46.580559599940386 -23.5412749663...  c_332423
# 1890585  LINESTRING (-46.679945711926116 -23.6539776709...  c_161700
# 669385   LINESTRING (-46.626850111421895 -23.5418705708...   c_88105
# 3699239  LINESTRING (-46.663868898549715 -23.6231362423...  c_421171
# 44687    LINESTRING (-46.70097108746287 -23.69615686057...    c_2093
#
#                data   hora dia_semana tipo_acidente  qtde_vitimas  \
# 3336118     13/5/19  19:30        NaN           NaN           NaN
# 1890585  07/12/2021  09:30        NaN           NaN           NaN
# 669385   05/12/2022  11:00        NaN           NaN           NaN
# 3699239  27/10/2023  16:00        NaN           NaN           NaN
# 44687      23/10/19  18:00        NaN           NaN           NaN
#
#          tamanho_congestionamento media_grau hora_valor minuto_valor  \
# 3336118                    1190.0        NaN         19           30
# 1890585                    1300.0        NaN         09           30
# 669385                     1680.0        NaN         11           00
# 3699239                     710.0        NaN         16           00
# 44687                       740.0        NaN         18           00
#
#         dia_valor mes_valor ano_valor
# 3336118        13        05      2019
# 1890585        07        12      2021
# 669385         05        12      2022
# 3699239        27        10      2023
# 44687          23        10      2019

# %%
print(f'{datetime.now().strftime("%H:%M:%S")}\tIniciando concatenacao dos campos de data (3 min)')

df_arestas['data_hora'] = df_arestas.apply(lambda a : 
        f"{a['dia_valor']}/{a['mes_valor']}/{a['ano_valor']} {a['hora_valor']}:{a['minuto_valor']}:00", axis = 1)

print(f'{datetime.now().strftime("%H:%M:%S")}\tFim da concatenação')
# Out:
# 22:52:16	Iniciando concatenacao dos campos de data (3 min)
# 22:54:00	Fim da concatenação

# %%
df_arestas = df_arestas[['vertice_a', 'vertice_b', 'geometry', 'index', 
            'data_hora', 'tipo_acidente', 'qtde_vitimas',
            'tamanho_congestionamento']]

# %%
n = len(df_arestas) # 5362932
df_arestas = df_arestas.drop_duplicates(['vertice_a', 'vertice_b', 'data_hora', 'tipo_acidente'])

print(n - len(df_arestas), 'registros deletados') # 5062248
# Out:
# 342325 registros deletados

# %%
len(df_arestas) # 5007436
# Out:
# 5007436

# %%
df_arestas.to_csv('data/arestas/0_arestas_completo.csv')
